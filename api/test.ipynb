# %%
import pandas
import pickle

# %%
with open('/Users/rahulvashisth/Downloads/Telegram Download/CampusX DSMP/Week 37-Capstone Project/Self/api/dataset/5.3_dataset_final.pkl','rb') as f:
    df = pickle.load(f)

# %%
df
# Out:
#           sector  super_area  bedrooms  bathroom balcony    age_possession  \
# 0      sector 39   1278.0000         2         2       2   1 to 5 year old
# 1          sohna    682.3526         2         2       2   1 to 5 year old
# 2      sector 71   1198.0000         2         2       2      10+ year old
# 3      sector 82   3240.0000         4         4       2   0 to 1 year old
# 4          sohna   1065.0000         2         2       2   0 to 1 year old
# ...          ...         ...       ...       ...     ...               ...
# 5584       sohna   1313.5000         4         4       2  5 to 10 year old
# 5585   sector 99   3500.0000         4         4      3+   1 to 5 year old
# 5586   sector 92   1628.0000         3         4      3+   1 to 5 year old
# 5587   sector 65   2916.6800         3         3       2   0 to 1 year old
# 5588  sector 70a   2150.0000         3         3       3   1 to 5 year old
#
#       servant_room luxury_category  parking building_type
# ...

# %%
df.columns
# Out:
# Index(['sector', 'super_area', 'bedrooms', 'bathroom', 'balcony',
#        'age_possession', 'servant_room', 'luxury_category', 'parking',
#        'building_type'],
#       dtype='object')

# %%
df['bedrooms'].describe()
# Out:
# count    5589.000000
# mean        2.963142
# std         0.714209
# min         1.000000
# 25%         3.000000
# 50%         3.000000
# 75%         3.000000
# max         6.000000
# Name: bedrooms, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5589 entries, 0 to 5588
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   sector           5589 non-null   object
#  1   super_area       5589 non-null   float64
#  2   bedrooms         5589 non-null   int64
#  3   bathroom         5589 non-null   int64
#  4   balcony          5589 non-null   object
#  5   age_possession   5589 non-null   object
#  6   servant_room     5589 non-null   int64
#  7   luxury_category  5589 non-null   object
#  8   parking          5589 non-null   int64
#  9   building_type    5589 non-null   object
# dtypes: float64(1), int64(4), object(5)
# memory usage: 436.8+ KB

# %%
df['luxury_category'].unique()
# Out:
# array(['medium', 'high', 'low'], dtype=object)

# %%
with open('/Users/rahulvashisth/Downloads/Telegram Download/CampusX DSMP/Week 37-Capstone Project/Self/api/model/5.2_pipeline.pkl','rb') as f:
    model = pickle.load(f)

# %%
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 model.feature_names_in_['luxury_category']
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices
